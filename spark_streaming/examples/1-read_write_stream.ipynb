# %% [markdown]
# <a href="https://colab.research.google.com/github/vaniamv/dataprocessing/blob/main/spark_streaming/examples/1-read_write_stream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read & Write Stream
# - readStream()
# - writeStream()
# - Streaming Dataframe

# %% [markdown]
# # Setting up PySpark

# %%
# %pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master('local').appName('Test streaming').getOrCreate()

# %% [markdown]
# # readStream with format "rate"
# - readStream
# - format("rate")

# %%
import pyspark.sql.functions as F

# read stream
stream = spark.readStream.format("rate").load()

# %%
type(stream)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
# checking if it's streaming dataframe
stream.isStreaming
# Out:
# True

# %%
# should be false
data = [("c1", "v1"), ("c2", "v2")]
columns = ["col1", "col2"]
df = spark.createDataFrame(data, columns)
df.isStreaming
# Out:
# False

# %%
# apply normal dataframe operations
stream.printSchema()
# Out:
# root
#  |-- timestamp: timestamp (nullable = true)
#  |-- value: long (nullable = true)

# %%
# Queries with streaming sources must be executed with writeStream.start();
# stream.show()
stream.count()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-8-2c876bdc4c4f> in <cell line: 3>()
#       1 # Queries with streaming sources must be executed with writeStream.start();
#       2 # stream.show()
# ----> 3 stream.count()
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py in count(self)
#    1238         3
#    1239         """
# -> 1240         return int(self._jdf.count())
#    1241
#    1242     def collect(self) -> List[Row]:
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
#    1324
#
# /usr/local/lib/python3.10/dist-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     183                 # Hide where the exception came from that shows a non-Pythonic
#     184                 # JVM exception message.
# --> 185                 raise converted from None
#     186             else:
#     187                 raise
#
# AnalysisException: Queries with streaming sources must be executed with writeStream.start();
# rate

# %% [markdown]
# # Transfor streaming dataframe

# %%
transformed = stream.withColumn("value2", F.col("value") * 2)

# %%
transformed.isStreaming
# Out:
# True

# %% [markdown]
# # write streaming dataframe - format memory
# - writeStream
# - format("memory")
# - queryName
# - outputMode
# - start

# %%
query = (transformed.writeStream
  .format('memory')
  .queryName('rate_report')
  .outputMode('append')
  .start()
)

# %% [markdown]
# # Checking result table

# %%
# StreamingQuery
type(query)
# Out:
# pyspark.sql.streaming.query.StreamingQuery

# %%
print(spark.table("rate_report").count())
spark.table("rate_report").show(20, False)

# one line per second
# Out:
# 26
# +----------------------+-----+------+
# |timestamp             |value|value2|
# +----------------------+-----+------+
# |2024-11-23 14:12:59.84|0    |0     |
# |2024-11-23 14:13:00.84|1    |2     |
# |2024-11-23 14:13:01.84|2    |4     |
# |2024-11-23 14:13:02.84|3    |6     |
# |2024-11-23 14:13:03.84|4    |8     |
# |2024-11-23 14:13:04.84|5    |10    |
# |2024-11-23 14:13:05.84|6    |12    |
# |2024-11-23 14:13:06.84|7    |14    |
# |2024-11-23 14:13:07.84|8    |16    |
# |2024-11-23 14:13:08.84|9    |18    |
# |2024-11-23 14:13:09.84|10   |20    |
# |2024-11-23 14:13:10.84|11   |22    |
# |2024-11-23 14:13:11.84|12   |24    |
# |2024-11-23 14:13:12.84|13   |26    |
# |2024-11-23 14:13:13.84|14   |28    |
# |2024-11-23 14:13:14.84|15   |30    |
# |2024-11-23 14:13:15.84|16   |32    |
# |2024-11-23 14:13:16.84|17   |34    |
# |2024-11-23 14:13:17.84|18   |36    |
# |2024-11-23 14:13:18.84|19   |38    |
# +----------------------+-----+------+
# only showing top 20 rows

# %%
query.status
# Out:
# {'message': 'Waiting for data to arrive',
#  'isDataAvailable': False,
#  'isTriggerActive': False}

# %%
query.isActive
# Out:
# True

# %%
query.recentProgress
# Out:
# [{'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:12:59.973Z',
#   'batchId': 0,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'addBatch': 1461,
#    'commitOffsets': 72,
#    'getBatch': 4,
#    'latestOffset': 0,
#    'queryPlanning': 84,
#    'triggerExecution': 1717,
#    'walCommit': 61},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': None,
#     'endOffset': 0,
#     'latestOffset': 0,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:01.747Z',
#   'batchId': 1,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 0.5636978579481398,
#   'processedRowsPerSecond': 1.1682242990654206,
#   'durationMs': {'addBatch': 664,
#    'commitOffsets': 58,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 29,
#    'triggerExecution': 856,
#    'walCommit': 100},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 0,
#     'endOffset': 1,
#     'latestOffset': 1,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 0.5636978579481398,
#     'processedRowsPerSecond': 1.1682242990654206}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:02.606Z',
#   'batchId': 2,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 1.1641443538998837,
#   'processedRowsPerSecond': 3.6363636363636362,
#   'durationMs': {'addBatch': 153,
#    'commitOffsets': 50,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 21,
#    'triggerExecution': 275,
#    'walCommit': 49},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 1,
#     'endOffset': 2,
#     'latestOffset': 2,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 1.1641443538998837,
#     'processedRowsPerSecond': 3.6363636363636362}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:02.884Z',
#   'batchId': 3,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 3.597122302158273,
#   'processedRowsPerSecond': 3.2679738562091503,
#   'durationMs': {'addBatch': 151,
#    'commitOffsets': 57,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 47,
#    'triggerExecution': 306,
#    'walCommit': 45},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 2,
#     'endOffset': 3,
#     'latestOffset': 3,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 3.597122302158273,
#     'processedRowsPerSecond': 3.2679738562091503}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:03.850Z',
#   'batchId': 4,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 2.6455026455026456,
#   'durationMs': {'addBatch': 235,
#    'commitOffsets': 62,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 20,
#    'triggerExecution': 378,
#    'walCommit': 59},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 3,
#     'endOffset': 4,
#     'latestOffset': 4,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 2.6455026455026456}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:04.847Z',
#   'batchId': 5,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 1.451378809869376,
#   'durationMs': {'addBatch': 350,
#    'commitOffsets': 136,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 59,
#    'triggerExecution': 689,
#    'walCommit': 142},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 4,
#     'endOffset': 5,
#     'latestOffset': 5,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 1.451378809869376}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:05.845Z',
#   'batchId': 6,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 76.92307692307692,
#   'processedRowsPerSecond': 1.1750881316098707,
#   'durationMs': {'addBatch': 330,
#    'commitOffsets': 141,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 70,
#    'triggerExecution': 851,
#    'walCommit': 305},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 5,
#     'endOffset': 6,
#     'latestOffset': 6,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 76.92307692307692,
#     'processedRowsPerSecond': 1.1750881316098707}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:06.843Z',
#   'batchId': 7,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 2.3255813953488373,
#   'durationMs': {'addBatch': 175,
#    'commitOffsets': 116,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 53,
#    'triggerExecution': 430,
#    'walCommit': 84},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 6,
#     'endOffset': 7,
#     'latestOffset': 7,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 2.3255813953488373}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:07.844Z',
#   'batchId': 8,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 2.0,
#   'durationMs': {'addBatch': 179,
#    'commitOffsets': 132,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 32,
#    'triggerExecution': 500,
#    'walCommit': 155},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 7,
#     'endOffset': 8,
#     'latestOffset': 8,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 2.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:08.850Z',
#   'batchId': 9,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 1.773049645390071,
#   'durationMs': {'addBatch': 196,
#    'commitOffsets': 176,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 41,
#    'triggerExecution': 564,
#    'walCommit': 151},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 8,
#     'endOffset': 9,
#     'latestOffset': 9,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 1.773049645390071}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:09.845Z',
#   'batchId': 10,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 3.623188405797101,
#   'durationMs': {'addBatch': 118,
#    'commitOffsets': 53,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 36,
#    'triggerExecution': 276,
#    'walCommit': 65},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 9,
#     'endOffset': 10,
#     'latestOffset': 10,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 3.623188405797101}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:10.843Z',
#   'batchId': 11,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 5.181347150259067,
#   'durationMs': {'addBatch': 82,
#    'commitOffsets': 52,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 18,
#    'triggerExecution': 193,
#    'walCommit': 40},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 10,
#     'endOffset': 11,
#     'latestOffset': 11,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 5.181347150259067}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:11.842Z',
#   'batchId': 12,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 5.434782608695652,
#   'durationMs': {'addBatch': 83,
#    'commitOffsets': 48,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 18,
#    'triggerExecution': 184,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 11,
#     'endOffset': 12,
#     'latestOffset': 12,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 5.434782608695652}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:12.842Z',
#   'batchId': 13,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 2.2172949002217295,
#   'durationMs': {'addBatch': 165,
#    'commitOffsets': 166,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 50,
#    'triggerExecution': 451,
#    'walCommit': 68},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 12,
#     'endOffset': 13,
#     'latestOffset': 13,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 2.2172949002217295}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:13.840Z',
#   'batchId': 14,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 2.6954177897574123,
#   'durationMs': {'addBatch': 151,
#    'commitOffsets': 175,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 12,
#    'triggerExecution': 371,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 13,
#     'endOffset': 14,
#     'latestOffset': 14,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 2.6954177897574123}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:14.848Z',
#   'batchId': 15,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 5.376344086021505,
#   'durationMs': {'addBatch': 95,
#    'commitOffsets': 41,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 22,
#    'triggerExecution': 186,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 14,
#     'endOffset': 15,
#     'latestOffset': 15,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 5.376344086021505}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:15.848Z',
#   'batchId': 16,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.1020408163265305,
#   'durationMs': {'addBatch': 91,
#    'commitOffsets': 46,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 21,
#    'triggerExecution': 196,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 15,
#     'endOffset': 16,
#     'latestOffset': 16,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.1020408163265305}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:16.843Z',
#   'batchId': 17,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 2.793296089385475,
#   'durationMs': {'addBatch': 135,
#    'commitOffsets': 94,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 27,
#    'triggerExecution': 358,
#    'walCommit': 102},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 16,
#     'endOffset': 17,
#     'latestOffset': 17,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 2.793296089385475}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:17.844Z',
#   'batchId': 18,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 1.2836970474967908,
#   'durationMs': {'addBatch': 244,
#    'commitOffsets': 434,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 54,
#    'triggerExecution': 779,
#    'walCommit': 46},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 17,
#     'endOffset': 18,
#     'latestOffset': 18,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 1.2836970474967908}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:18.840Z',
#   'batchId': 19,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 28.57142857142857,
#   'processedRowsPerSecond': 2.0876826722338206,
#   'durationMs': {'addBatch': 180,
#    'commitOffsets': 95,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 30,
#    'triggerExecution': 479,
#    'walCommit': 172},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 18,
#     'endOffset': 19,
#     'latestOffset': 19,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 28.57142857142857,
#     'processedRowsPerSecond': 2.0876826722338206}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:19.847Z',
#   'batchId': 20,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.58659217877095,
#   'durationMs': {'addBatch': 76,
#    'commitOffsets': 47,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 10,
#    'triggerExecution': 179,
#    'walCommit': 45},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 19,
#     'endOffset': 20,
#     'latestOffset': 20,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.58659217877095}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:20.844Z',
#   'batchId': 21,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.780346820809249,
#   'durationMs': {'addBatch': 88,
#    'commitOffsets': 34,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 21,
#    'triggerExecution': 173,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 20,
#     'endOffset': 21,
#     'latestOffset': 21,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.780346820809249}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:21.846Z',
#   'batchId': 22,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 5.813953488372094,
#   'durationMs': {'addBatch': 79,
#    'commitOffsets': 46,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 12,
#    'triggerExecution': 172,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 21,
#     'endOffset': 22,
#     'latestOffset': 22,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 5.813953488372094}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:22.840Z',
#   'batchId': 23,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 5.319148936170213,
#   'durationMs': {'addBatch': 82,
#    'commitOffsets': 63,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 14,
#    'triggerExecution': 188,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 22,
#     'endOffset': 23,
#     'latestOffset': 23,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 5.319148936170213}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:23.850Z',
#   'batchId': 24,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 2.9850746268656714,
#   'durationMs': {'addBatch': 112,
#    'commitOffsets': 173,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 12,
#    'triggerExecution': 335,
#    'walCommit': 38},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 23,
#     'endOffset': 24,
#     'latestOffset': 24,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 2.9850746268656714}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:24.846Z',
#   'batchId': 25,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.0606060606060606,
#   'durationMs': {'addBatch': 74,
#    'commitOffsets': 42,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 16,
#    'triggerExecution': 165,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 24,
#     'endOffset': 25,
#     'latestOffset': 25,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.0606060606060606}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:25.849Z',
#   'batchId': 26,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.756756756756757,
#   'durationMs': {'addBatch': 61,
#    'commitOffsets': 46,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 11,
#    'triggerExecution': 148,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 25,
#     'endOffset': 26,
#     'latestOffset': 26,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.756756756756757}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:26.846Z',
#   'batchId': 27,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 2.092050209205021,
#   'durationMs': {'addBatch': 174,
#    'commitOffsets': 230,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 20,
#    'triggerExecution': 478,
#    'walCommit': 53},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 26,
#     'endOffset': 27,
#     'latestOffset': 27,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 2.092050209205021}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:27.840Z',
#   'batchId': 28,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 5.405405405405405,
#   'durationMs': {'addBatch': 89,
#    'commitOffsets': 48,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 11,
#    'triggerExecution': 185,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 27,
#     'endOffset': 28,
#     'latestOffset': 28,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 5.405405405405405}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:28.846Z',
#   'batchId': 29,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.9171597633136095,
#   'durationMs': {'addBatch': 77,
#    'commitOffsets': 52,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 9,
#    'triggerExecution': 169,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 28,
#     'endOffset': 29,
#     'latestOffset': 29,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.9171597633136095}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:29.842Z',
#   'batchId': 30,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 3.53356890459364,
#   'durationMs': {'addBatch': 102,
#    'commitOffsets': 109,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 18,
#    'triggerExecution': 283,
#    'walCommit': 54},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 29,
#     'endOffset': 30,
#     'latestOffset': 30,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 3.53356890459364}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:30.841Z',
#   'batchId': 31,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 2.5839793281653747,
#   'durationMs': {'addBatch': 165,
#    'commitOffsets': 102,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 19,
#    'triggerExecution': 387,
#    'walCommit': 99},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 30,
#     'endOffset': 31,
#     'latestOffset': 31,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 2.5839793281653747}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:31.847Z',
#   'batchId': 32,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 4.484304932735426,
#   'durationMs': {'addBatch': 102,
#    'commitOffsets': 69,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 10,
#    'triggerExecution': 223,
#    'walCommit': 41},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 31,
#     'endOffset': 32,
#     'latestOffset': 32,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 4.484304932735426}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:32.842Z',
#   'batchId': 33,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 2.873563218390805,
#   'durationMs': {'addBatch': 99,
#    'commitOffsets': 207,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 13,
#    'triggerExecution': 348,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 32,
#     'endOffset': 33,
#     'latestOffset': 33,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 2.873563218390805}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:33.849Z',
#   'batchId': 34,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.042253521126761,
#   'durationMs': {'addBatch': 66,
#    'commitOffsets': 38,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 10,
#    'triggerExecution': 142,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 33,
#     'endOffset': 34,
#     'latestOffset': 34,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.042253521126761}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:34.842Z',
#   'batchId': 35,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 6.024096385542168,
#   'durationMs': {'addBatch': 82,
#    'commitOffsets': 46,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 10,
#    'triggerExecution': 166,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 34,
#     'endOffset': 35,
#     'latestOffset': 35,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 6.024096385542168}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:35.849Z',
#   'batchId': 36,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 7.142857142857142,
#   'durationMs': {'addBatch': 55,
#    'commitOffsets': 43,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 10,
#    'triggerExecution': 140,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 35,
#     'endOffset': 36,
#     'latestOffset': 36,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 7.142857142857142}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:36.845Z',
#   'batchId': 37,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.4935064935064934,
#   'durationMs': {'addBatch': 80,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 9,
#    'triggerExecution': 154,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 36,
#     'endOffset': 37,
#     'latestOffset': 37,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.4935064935064934}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:37.848Z',
#   'batchId': 38,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 6.0606060606060606,
#   'durationMs': {'addBatch': 82,
#    'commitOffsets': 38,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 16,
#    'triggerExecution': 165,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 37,
#     'endOffset': 38,
#     'latestOffset': 38,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 6.0606060606060606}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:38.850Z',
#   'batchId': 39,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 6.8965517241379315,
#   'durationMs': {'addBatch': 66,
#    'commitOffsets': 36,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 12,
#    'triggerExecution': 145,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 38,
#     'endOffset': 39,
#     'latestOffset': 39,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 6.8965517241379315}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:39.840Z',
#   'batchId': 40,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 3.3112582781456954,
#   'durationMs': {'addBatch': 122,
#    'commitOffsets': 138,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 9,
#    'triggerExecution': 302,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 39,
#     'endOffset': 40,
#     'latestOffset': 40,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 3.3112582781456954}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '5876aac2-5324-41d4-8b65-02a5bafb56c4',
#   'runId': '388fd28e-3663-47bc-b696-12a290f4097e',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:13:40.844Z',
#   'batchId': 41,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.130081300813009,
#   'durationMs': {'addBatch': 53,
#    'commitOffsets': 30,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 9,
#    'triggerExecution': 123,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 40,
#     'endOffset': 41,
#     'latestOffset': 41,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.130081300813009}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}}]

# %%
query.lastProgress['batchId']
# Out:
# 46

# %% [markdown]
# # Stop streaming

# %%
query.stop()

# %%
spark.sql("select * from rate_report").count()
# Out:
# 50

# %%
# awaitTermination

# %% [markdown]
# # Increase rows per second (rate)

# %%
# read stream
stream = spark.readStream.format("rate").option("rowsPerSecond", 20).load()  #para cada segundo cria 20 linhas

transformed = stream.withColumn("value2", F.col("value") * 2)

query = (transformed.writeStream
  .format('memory')
  .queryName('rate_
# |2024-11-23 14:17:56.898|59   |118   |
# |2024-11-23 14:17:56.948|60   |120   |
# |2024-11-23 14:17:56.998|61   |122   |
# |2024-11-23 14:17:57.048|62   |124   |
# |2024-11-23 14:17:57.098|63   |126   |
# |2024-11-23 14:17:57.148|64   |128   |
# |2024-11-23 14:17:57.198|65   |130   |
# |2024-11-23 14:17:57.248|66   |132   |
# |2024-11-23 14:17:57.298|67   |134   |
# |2024-11-23 14:17:57.348|68   |136   |
# |2024-11-23 14:17:57.398|69   |138   |
# |2024-11-23 14:17:57.448|70   |140   |
# |2024-11-23 14:17:57.498|71   |142   |
# |2024-11-23 14:17:57.548|72   |144   |
# |2024-11-23 14:17:57.598|73   |146   |
# |2024-11-23 14:17:57.648|74   |148   |
# |2024-11-23 14:17:57.698|75   |150   |
# |2024-11-23 14:17:57.748|76   |152   |
# |2024-11-23 14:17:57.798|77   |154   |
# |2024-11-23 14:17:57.848|78   |156   |
# |2024-11-23 14:17:57.898|79   |158   |
# |2024-11-23 14:17:57.948|80   |160   |
# |2024-11-23 14:17:57.998|81   |162   |
# |2024-11-23 14:17:58.048|82   |164   |
# |2024-11-23 14:17:58.098|83   |166   |
# |2024-11-23 14:17:58.148|84   |168   |
# |2024-11-23 14:17:58.198|85   |170   |
# |2024-11-23 14:17:58.248|86   |172   |
# |2024-11-23 14:17:58.298|87   |174   |
# |2024-11-23 14:17:58.348|88   |176   |
# |2024-11-23 14:17:58.398|89   |178   |
# |2024-11-23 14:17:58.448|90   |180   |
# |2024-11-23 14:17:58.498|91   |182   |
# |2024-11-23 14:17:58.548|92   |184   |
# |2024-11-23 14:17:58.598|93   |186   |
# |2024-11-23 14:17:58.648|94   |188   |
# |2024-11-23 14:17:58.698|95   |190   |
# |2024-11-23 14:17:58.748|96   |192   |
# |2024-11-23 14:17:58.798|97   |194   |
# |2024-11-23 14:17:58.848|98   |196   |
# |2024-11-23 14:17:58.898|99   |198   |
# +-----------------------+-----+------+
# only showing top 100 rows

# %%
query.lastProgress['sources'][0]
# Out:
# {'description': 'RateStreamV2[rowsPerSecond=20, rampUpTimeSeconds=0, numPartitions=default',
#  'startOffset': 400,
#  'endOffset': 401,
#  'latestOffset': 401,
#  'numInputRows': 20,
#  'inputRowsPerSecond': 2000.0,
#  'processedRowsPerSecond': 246.91358024691357}

# %%
query.lastProgress['sources'][0]['numInputRows']
# Out:
# 20

# %%
for batch in query.recentProgress:
  print(f"timestamp - {batch['timestamp']}")
  print(f"batchId - {batch['batchId']}")
  print(f"numInputRows - {batch['numInputRows']}")
  print("--")
# Out:
# timestamp - 2024-11-23T14:23:13.958Z
# batchId - 320
# numInputRows - 20
# --
# timestamp - 2024-11-23T14:23:14.954Z
# batchId - 321
# numInputRows - 20
# --
# timestamp - 2024-11-23T14:23:15.951Z
# batchId - 322
# numInputRows - 20
# --
# timestamp - 2024-11-23T14:23:16.953Z
# batchId - 323
# numInputRows - 20
# --
# timestamp - 2024-11-23T14:23:17.955Z
# batchId - 324
# numInputRows - 20
# --
# timestamp - 2024-11-23T14:23:18.958Z
# batchId - 325
# numInputRows - 20
# --
# timestamp - 2024-11-23T14:23:19.956Z
# batchId - 326
# numInputRows - 20
# --
# timestamp - 2024-11-23T14:23:20.958Z
# batchId - 327
# numInputRows - 20
# --
# timestamp - 2024-11-23T14:23:21.950Z
# batchId - 328
# numInputRows - 20
# --
# timestamp - 2024-11-23T14:23