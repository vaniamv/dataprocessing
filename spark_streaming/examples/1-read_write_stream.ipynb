# %% [markdown]
# <a href="https://colab.research.google.com/github/vaniamv/dataprocessing/blob/main/spark_streaming/examples/1-read_write_stream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read & Write Stream
# - readStream()
# - writeStream()
# - Streaming Dataframe

# %% [markdown]
# # Setting up PySpark

# %%
# %pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master('local').appName('Test streaming').getOrCreate()

# %% [markdown]
# # readStream with format "rate"
# - readStream
# - format("rate")

# %%
import pyspark.sql.functions as F

# read stream
stream = spark.readStream.format("rate").load()

# %%
type(stream)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
# checking if it's streaming dataframe
stream.isStreaming
# Out:
# True

# %%
# should be false
data = [("c1", "v1"), ("c2", "v2")]
columns = ["col1", "col2"]
df = spark.createDataFrame(data, columns)
df.isStreaming
# Out:
# False

# %%
# apply normal dataframe operations
stream.printSchema()
# Out:
# root
#  |-- timestamp: timestamp (nullable = true)
#  |-- value: long (nullable = true)

# %%
# Queries with streaming sources must be executed with writeStream.start();
# stream.show()
stream.count()

# %% [markdown]
# # Transfor streaming dataframe

# %%
transformed = stream.withColumn("value2", F.col("value") * 2)

# %%
transformed.isStreaming
# Out:
# True

# %% [markdown]
# # write streaming dataframe - format memory
# - writeStream
# - format("memory")
# - queryName
# - outputMode
# - start

# %%
query = (transformed.writeStream
  .format('memory')
  .queryName('rate_report')
  .outputMode('append')
  .start()
)

# %% [markdown]
# # Checking result table

# %%
# StreamingQuery
type(query)
# Out:
# pyspark.sql.streaming.query.StreamingQuery

# %%
print(spark.table("rate_report").count())
spark.table("rate_report").show(20, False)

# one line per second
# Out:
# 304
# +----------------------+-----+------+
# |timestamp             |value|value2|
# +----------------------+-----+------+
# |2024-11-22 15:04:15.04|0    |0     |
# |2024-11-22 15:04:16.04|1    |2     |
# |2024-11-22 15:04:17.04|2    |4     |
# |2024-11-22 15:04:18.04|3    |6     |
# |2024-11-22 15:04:19.04|4    |8     |
# |2024-11-22 15:04:20.04|5    |10    |
# |2024-11-22 15:04:21.04|6    |12    |
# |2024-11-22 15:04:22.04|7    |14    |
# |2024-11-22 15:04:23.04|8    |16    |
# |2024-11-22 15:04:24.04|9    |18    |
# |2024-11-22 15:04:25.04|10   |20    |
# |2024-11-22 15:04:26.04|11   |22    |
# |2024-11-22 15:04:27.04|12   |24    |
# |2024-11-22 15:04:28.04|13   |26    |
# |2024-11-22 15:04:29.04|14   |28    |
# |2024-11-22 15:04:30.04|15   |30    |
# |2024-11-22 15:04:31.04|16   |32    |
# |2024-11-22 15:04:32.04|17   |34    |
# |2024-11-22 15:04:33.04|18   |36    |
# |2024-11-22 15:04:34.04|19   |38    |
# +----------------------+-----+------+
# only showing top 20 rows

# %%
query.status
# Out:
# {'message': 'Waiting for data to arrive',
#  'isDataAvailable': False,
#  'isTriggerActive': False}

# %%
query.isActive
# Out:
# True

# %%
query.recentProgress
# Out:
# [{'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:44.044Z',
#   'batchId': 149,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.658227848101266,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 79,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 148,
#     'endOffset': 149,
#     'latestOffset': 149,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.658227848101266}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:45.047Z',
#   'batchId': 150,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 13.333333333333334,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 24,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 75,
#    'walCommit': 23},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 149,
#     'endOffset': 150,
#     'latestOffset': 150,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 13.333333333333334}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:46.044Z',
#   'batchId': 151,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.76470588235294,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 85,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 150,
#     'endOffset': 151,
#     'latestOffset': 151,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.76470588235294}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:47.042Z',
#   'batchId': 152,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.157894736842106,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 22,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 76,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 151,
#     'endOffset': 152,
#     'latestOffset': 152,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.157894736842106}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:48.041Z',
#   'batchId': 153,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.25925925925926,
#   'durationMs': {'addBatch': 33,
#    'commitOffsets': 34,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 108,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 152,
#     'endOffset': 153,
#     'latestOffset': 153,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.25925925925926}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:49.045Z',
#   'batchId': 154,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.751937984496124,
#   'durationMs': {'addBatch': 46,
#    'commitOffsets': 41,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 129,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 153,
#     'endOffset': 154,
#     'latestOffset': 154,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.751937984496124}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:50.046Z',
#   'batchId': 155,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.204081632653061,
#   'durationMs': {'addBatch': 34,
#    'commitOffsets': 34,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 98,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 154,
#     'endOffset': 155,
#     'latestOffset': 155,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.204081632653061}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:51.045Z',
#   'batchId': 156,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.513513513513514,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 23,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 74,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 155,
#     'endOffset': 156,
#     'latestOffset': 156,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.513513513513514}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:52.049Z',
#   'batchId': 157,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.751937984496124,
#   'durationMs': {'addBatch': 50,
#    'commitOffsets': 44,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 129,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 156,
#     'endOffset': 157,
#     'latestOffset': 157,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.751937984496124}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:53.047Z',
#   'batchId': 158,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.526315789473685,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 95,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 157,
#     'endOffset': 158,
#     'latestOffset': 158,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.526315789473685}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:54.044Z',
#   'batchId': 159,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.820512820512821,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 78,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 158,
#     'endOffset': 159,
#     'latestOffset': 159,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.820512820512821}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:55.046Z',
#   'batchId': 160,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 11.49425287356322,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 87,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 159,
#     'endOffset': 160,
#     'latestOffset': 160,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 11.49425287356322}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:56.046Z',
#   'batchId': 161,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.633587786259541,
#   'durationMs': {'addBatch': 37,
#    'commitOffsets': 44,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 131,
#    'walCommit': 43},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 160,
#     'endOffset': 161,
#     'latestOffset': 161,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.633587786259541}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:57.042Z',
#   'batchId': 162,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 11.627906976744187,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 86,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 161,
#     'endOffset': 162,
#     'latestOffset': 162,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 11.627906976744187}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:58.040Z',
#   'batchId': 163,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.869565217391305,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 92,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 162,
#     'endOffset': 163,
#     'latestOffset': 163,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.869565217391305}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:06:59.047Z',
#   'batchId': 164,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.195121951219512,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 82,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 163,
#     'endOffset': 164,
#     'latestOffset': 164,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.195121951219512}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:00.045Z',
#   'batchId': 165,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 3.5087719298245617,
#   'durationMs': {'addBatch': 99,
#    'commitOffsets': 145,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 285,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 164,
#     'endOffset': 165,
#     'latestOffset': 165,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 3.5087719298245617}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:01.046Z',
#   'batchId': 166,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.433962264150944,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 34,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 106,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 165,
#     'endOffset': 166,
#     'latestOffset': 166,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.433962264150944}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:02.046Z',
#   'batchId': 167,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.820512820512821,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 78,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 166,
#     'endOffset': 167,
#     'latestOffset': 167,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.820512820512821}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:03.046Z',
#   'batchId': 168,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.048192771084336,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 83,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 167,
#     'endOffset': 168,
#     'latestOffset': 168,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.048192771084336}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:04.043Z',
#   'batchId': 169,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.235955056179776,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 30,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 89,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 168,
#     'endOffset': 169,
#     'latestOffset': 169,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.235955056179776}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:05.044Z',
#   'batchId': 170,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.904761904761903,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 23,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 84,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 169,
#     'endOffset': 170,
#     'latestOffset': 170,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.904761904761903}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:06.041Z',
#   'batchId': 171,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.627906976744187,
#   'durationMs': {'addBatch': 31,
#    'commitOffsets': 26,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 86,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 170,
#     'endOffset': 171,
#     'latestOffset': 171,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.627906976744187}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:07.041Z',
#   'batchId': 172,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.363636363636365,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 32,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 88,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 171,
#     'endOffset': 172,
#     'latestOffset': 172,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.363636363636365}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:08.046Z',
#   'batchId': 173,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.649717514124294,
#   'durationMs': {'addBatch': 51,
#    'commitOffsets': 95,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 177,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 172,
#     'endOffset': 173,
#     'latestOffset': 173,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.649717514124294}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:09.043Z',
#   'batchId': 174,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.75268817204301,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 40,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 93,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 173,
#     'endOffset': 174,
#     'latestOffset': 174,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.75268817204301}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:10.050Z',
#   'batchId': 175,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.048192771084336,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 82,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 174,
#     'endOffset': 175,
#     'latestOffset': 175,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.048192771084336}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:11.046Z',
#   'batchId': 176,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.5,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 80,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 175,
#     'endOffset': 176,
#     'latestOffset': 176,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.5}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:12.043Z',
#   'batchId': 177,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.264462809917356,
#   'durationMs': {'addBatch': 43,
#    'commitOffsets': 36,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 121,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 176,
#     'endOffset': 177,
#     'latestOffset': 177,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.264462809917356}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:13.040Z',
#   'batchId': 178,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.987012987012987,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 23,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 77,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 177,
#     'endOffset': 178,
#     'latestOffset': 178,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.987012987012987}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:14.042Z',
#   'batchId': 179,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.615384615384615,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 44,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 104,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 178,
#     'endOffset': 179,
#     'latestOffset': 179,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.615384615384615}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:15.044Z',
#   'batchId': 180,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.5,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 80,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 179,
#     'endOffset': 180,
#     'latestOffset': 180,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.5}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:16.045Z',
#   'batchId': 181,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.064516129032258,
#   'durationMs': {'addBatch': 56,
#    'commitOffsets': 37,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 124,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 180,
#     'endOffset': 181,
#     'latestOffset': 181,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.064516129032258}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:17.041Z',
#   'batchId': 182,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.345679012345679,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 23,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 81,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 181,
#     'endOffset': 182,
#     'latestOffset': 182,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.345679012345679}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:18.046Z',
#   'batchId': 183,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.513513513513514,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 74,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 182,
#     'endOffset': 183,
#     'latestOffset': 183,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.513513513513514}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:19.043Z',
#   'batchId': 184,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.75268817204301,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 38,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 93,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 183,
#     'endOffset': 184,
#     'latestOffset': 184,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.75268817204301}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:20.041Z',
#   'batchId': 185,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.904761904761903,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 31,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 84,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 184,
#     'endOffset': 185,
#     'latestOffset': 185,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.904761904761903}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:21.048Z',
#   'batchId': 186,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.849557522123893,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 113,
#    'walCommit': 60},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 185,
#     'endOffset': 186,
#     'latestOffset': 186,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.849557522123893}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:22.042Z',
#   'batchId': 187,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.904761904761903,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 23,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 84,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 186,
#     'endOffset': 187,
#     'latestOffset': 187,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.904761904761903}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:23.049Z',
#   'batchId': 188,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.523809523809524,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 34,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 105,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 187,
#     'endOffset': 188,
#     'latestOffset': 188,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.523809523809524}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:24.041Z',
#   'batchId': 189,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 4.385964912280701,
#   'durationMs': {'addBatch': 112,
#    'commitOffsets': 75,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 228,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 188,
#     'endOffset': 189,
#     'latestOffset': 189,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 4.385964912280701}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:25.047Z',
#   'batchId': 190,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.333333333333334,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 23,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 75,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 189,
#     'endOffset': 190,
#     'latestOffset': 190,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.333333333333334}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:26.046Z',
#   'batchId': 191,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 11.627906976744187,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 32,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 86,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 190,
#     'endOffset': 191,
#     'latestOffset': 191,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 11.627906976744187}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:27.048Z',
#   'batchId': 192,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.869565217391305,
#   'durationMs': {'addBatch': 31,
#    'commitOffsets': 31,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 92,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 191,
#     'endOffset': 192,
#     'latestOffset': 192,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.869565217391305}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:28.047Z',
#   'batchId': 193,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.11111111111111,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 90,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 192,
#     'endOffset': 193,
#     'latestOffset': 193,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.11111111111111}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:29.049Z',
#   'batchId': 194,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.987012987012987,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 77,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 193,
#     'endOffset': 194,
#     'latestOffset': 194,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.987012987012987}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:30.049Z',
#   'batchId': 195,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.49425287356322,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 87,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 194,
#     'endOffset': 195,
#     'latestOffset': 195,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.49425287356322}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:31.047Z',
#   'batchId': 196,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.820512820512821,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 23,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 78,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 195,
#     'endOffset': 196,
#     'latestOffset': 196,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.820512820512821}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:32.045Z',
#   'batchId': 197,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 3.4013605442176873,
#   'durationMs': {'addBatch': 43,
#    'commitOffsets': 219,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 294,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 196,
#     'endOffset': 197,
#     'latestOffset': 197,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 3.4013605442176873}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:33.041Z',
#   'batchId': 198,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.363636363636365,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 30,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 88,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 197,
#     'endOffset': 198,
#     'latestOffset': 198,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.363636363636365}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:34.043Z',
#   'batchId': 199,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.5,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 80,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 198,
#     'endOffset': 199,
#     'latestOffset': 199,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.5}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:35.049Z',
#   'batchId': 200,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.451612903225807,
#   'durationMs': {'addBatch': 45,
#    'commitOffsets': 66,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 8,
#    'triggerExecution': 155,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 199,
#     'endOffset': 200,
#     'latestOffset': 200,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.451612903225807}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:36.041Z',
#   'batchId': 201,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 5.617977528089888,
#   'durationMs': {'addBatch': 42,
#    'commitOffsets': 93,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 178,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 200,
#     'endOffset': 201,
#     'latestOffset': 201,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 5.617977528089888}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:37.043Z',
#   'batchId': 202,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.756756756756757,
#   'durationMs': {'addBatch': 45,
#    'commitOffsets': 61,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 148,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 201,
#     'endOffset': 202,
#     'latestOffset': 202,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.756756756756757}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:38.045Z',
#   'batchId': 203,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.157894736842106,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 76,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 202,
#     'endOffset': 203,
#     'latestOffset': 203,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.157894736842106}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:39.044Z',
#   'batchId': 204,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.363636363636365,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 88,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 203,
#     'endOffset': 204,
#     'latestOffset': 204,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.363636363636365}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:40.049Z',
#   'batchId': 205,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 3.952569169960474,
#   'durationMs': {'addBatch': 45,
#    'commitOffsets': 171,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 253,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 204,
#     'endOffset': 205,
#     'latestOffset': 205,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 3.952569169960474}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:07:41.043Z',
#   'batchId': 206,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.627906976744187,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 31,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 86,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 205,
#     'endOffset': 206,
#     'latestOffset': 206,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.627906976744187}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
# ...
#     'startOffset': 227,
#     'endOffset': 228,
#     'latestOffset': 228,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 5.2356020942408374}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:04.047Z',
#   'batchId': 229,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.874015748031496,
#   'durationMs': {'addBatch': 59,
#    'commitOffsets': 40,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 127,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 228,
#     'endOffset': 229,
#     'latestOffset': 229,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.874015748031496}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:05.045Z',
#   'batchId': 230,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.157894736842106,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 76,
#    'walCommit': 23},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 229,
#     'endOffset': 230,
#     'latestOffset': 230,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.157894736842106}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:06.043Z',
#   'batchId': 231,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.5,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 26,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 80,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 230,
#     'endOffset': 231,
#     'latestOffset': 231,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.5}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:07.046Z',
#   'batchId': 232,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.333333333333334,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 23,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 75,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 231,
#     'endOffset': 232,
#     'latestOffset': 232,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.333333333333334}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:08.043Z',
#   'batchId': 233,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.4074074074074066,
#   'durationMs': {'addBatch': 38,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 135,
#    'walCommit': 67},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 232,
#     'endOffset': 233,
#     'latestOffset': 233,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.4074074074074066}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:09.050Z',
#   'batchId': 234,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.987012987012987,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 22,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 77,
#    'walCommit': 23},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 233,
#     'endOffset': 234,
#     'latestOffset': 234,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.987012987012987}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:10.048Z',
#   'batchId': 235,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.658227848101266,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 79,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 234,
#     'endOffset': 235,
#     'latestOffset': 235,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.658227848101266}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:11.049Z',
#   'batchId': 236,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.49425287356322,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 87,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 235,
#     'endOffset': 236,
#     'latestOffset': 236,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.49425287356322}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:12.040Z',
#   'batchId': 237,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 3.8910505836575875,
#   'durationMs': {'addBatch': 92,
#    'commitOffsets': 121,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 257,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 236,
#     'endOffset': 237,
#     'latestOffset': 237,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 3.8910505836575875}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:13.046Z',
#   'batchId': 238,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.928571428571429,
#   'durationMs': {'addBatch': 32,
#    'commitOffsets': 36,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 112,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 237,
#     'endOffset': 238,
#     'latestOffset': 238,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.928571428571429}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:14.040Z',
#   'batchId': 239,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.658227848101266,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 79,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 238,
#     'endOffset': 239,
#     'latestOffset': 239,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.658227848101266}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:15.045Z',
#   'batchId': 240,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.363636363636365,
#   'durationMs': {'addBatch': 34,
#    'commitOffsets': 26,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 88,
#    'walCommit': 23},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 239,
#     'endOffset': 240,
#     'latestOffset': 240,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.363636363636365}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:16.045Z',
#   'batchId': 241,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 9.708737864077671,
#   'durationMs': {'addBatch': 32,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 8,
#    'triggerExecution': 103,
#    'walCommit': 33},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 240,
#     'endOffset': 241,
#     'latestOffset': 241,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 9.708737864077671}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:17.049Z',
#   'batchId': 242,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.513513513513514,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 23,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 74,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 241,
#     'endOffset': 242,
#     'latestOffset': 242,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.513513513513514}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:18.045Z',
#   'batchId': 243,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 13.513513513513514,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 23,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 74,
#    'walCommit': 23},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 242,
#     'endOffset': 243,
#     'latestOffset': 243,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 13.513513513513514}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:19.040Z',
#   'batchId': 244,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.513513513513514,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 74,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 243,
#     'endOffset': 244,
#     'latestOffset': 244,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.513513513513514}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:20.049Z',
#   'batchId': 245,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.128205128205128,
#   'durationMs': {'addBatch': 51,
#    'commitOffsets': 99,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 15,
#    'triggerExecution': 195,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 244,
#     'endOffset': 245,
#     'latestOffset': 245,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.128205128205128}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:21.048Z',
#   'batchId': 246,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.204081632653061,
#   'durationMs': {'addBatch': 32,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 17,
#    'triggerExecution': 98,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 245,
#     'endOffset': 246,
#     'latestOffset': 246,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.204081632653061}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'de7ef201-4f96-4a74-a300-f6b9e03fa6e0',
#   'runId': '1881ae5a-7787-4ef3-a4f5-57926f6161b3',
#   'name': 'rate_report',
#   'timestamp': '2024-11-22T15:08:22.041Z',
#   'batchId': 247,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.157894736842106,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 76,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 246,
#     'endOffset': 247,
#     'latestOffset': 247,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.157894736842106}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}}]

# %%
query.lastProgress['batchId']
# Out:
# 304

# %% [markdown]
# # Stop streaming

# %%
query.stop()

# %%
# awaitTermination

# %% [markdown]
# # Increase rows per second (rate)

# %%
# read stream
stream = spark.readStream.format("rate").option("rowsPerSecond", 20).load()

transformed = stream.withColumn("value2", F.col("value") * 2)

query = (transformed.writeStream
  .format('memory')
  .queryName('rate_report_2')
  .outputMode('append')
  .start()
)

# %%
print(spark.table("rate_report_2").count())
spark.table("rate_report_2").show(100, False)
# Out:
# 740
# +-----------------------+-----+------+
# |timestamp              |value|value2|
# +-----------------------+-----+------+
# |2024-11-22 15:16:27.485|0    |0     |
# |2024-11-22 15:16:27.535|1    |2     |
# |2024-11-22 15:16:27.585|2    |4     |
# |2024-11-22 15:16:27.635|3    |6     |
# |2024-11-22 15:16:27.685|4    |8     |
# |2024-11-22 15:16:27.735|5    |10    |
# |2024-11-22 15:16:27.785|6    |12    |
# |2024-11-22 15:16:27.835|7    |14    |
# |2024-11-22 15:16:27.885|8    |16    |
# |2024-11-22 15:16:27.935|9    |18    |
# |2024-11-22 15:16:27.985|10   |20    |
# |2024-11-22 15:16:28.035|11   |22    |
# |2024-11-22 15:16:28.085|12   |24    |
# |2024-11-22 15:16:28.135|13   |26    |
# |2024-11-22 15:16:28.185|14   |28    |
# |2024-11-22 15:16:28.235|15   |30    |
# |2024-11-22 15:16:28.285|16   |32    |
# |2024-11-22 15:16:28.335|17   |34    |
# |2024-11-22 15:16:28.385|18   |36    |
# |2024-11-22 15:16:28.435|19   |38    |
# |2024-11-22 15:16:28.485|20   |40    |
# |2024-11-22 15:16:28.535|21   |42    |
# |2024-11-22 15:16:28.585|22   |44    |
# |2024-11-22 15:16:28.635|23   |46    |
# |2024-11-22 15:16:28.685|24   |48    |
# |2024-11-22 15:16:28.735|25   |50    |
# |2024-11-22 15:16:28.785|26   |52    |
# |2024-11-22 15:16:28.835|27   |54    |
# |2024-11-22 15:16:28.885|28   |56    |
# |2024-11-22 15:16:28.935|29   |58    |
# |2024-11-22 15:16:28.985|30   |60    |
# |2024-11-22 15:16:29.035|31   |62    |
# |2024-11-22 15:16:29.085|32   |64    |
# |2024-11-22 15:16:29.135|33   |66    |
# |2024-11-22 15:16:29.185|34   |68    |
# |2024-11-22 15:16:29.235|35   |70    |
# |2024-11-22 15:16:29.285|36   |72    |
# |2024-11-22 15:16:29.335|37   |74    |
# |2024-11-22 15:16:29.385|38   |76    |
# |2024-11-22 15:16:29.435|39   |78    |
# |2024-11-22 15:16:29.485|40   |80    |
# |2024-11-22 15:16:29.535|41   |82    |
# |2024-11-22 15:16:29.585|42   |84    |
# |2024-11-22 15:16:29.635|43   |86    |
# |2024-11-22 15:16:29.685|44   |88    |
# |2024-11-22 15:16:29.735|45   |90    |
# |2024-11-22 15:16:29.785|46   |92    |
# |2024-11-22 15:16:29.835|47   |94    |
# |2024-11-22 15:16:29.885|48   |96    |
# |2024-11-22 15:16:29.935|49   |98    |
# |2024-11-22 15:16:29.985|50   |100   |
# |2024-11-22 15:16:30.035|51   |102   |
# |2024-11-22 15:16:30.085|52   |104   |
# |2024-11-22 15:16:30.135|53   |106   |
# |2024-11-22 15:16:30.185|54   |108   |
# |2024-11-22 15:16:30.235|55   |110   |
# |2024-11-22 15:16:30.285|56   |112   |
# |2024-11-22 15:16:30.335|57   |114   |
# |2024-11-22 15:16:30.385|58   |116   |
# |2024-11-22 15:16:30.435|59   |118   |
# |2024-11-22 15:16:30.485|60   |120   |
# |2024-11-22 15:16:30.535|61   |122   |
# |2024-11-22 15:16:30.585|62   |124   |
# |2024-11-22 15:16:30.635|63   |126   |
# |2024-11-22 15:16:30.685|64   |128   |
# |2024-11-22 15:16:30.735|65   |130   |
# |2024-11-22 15:16:30.785|66   |132   |
# |2024-11-22 15:16:30.835|67   |134   |
# |2024-11-22 15:16:30.885|68   |136   |
# |2024-11-22 15:16:30.935|69   |138   |
# |2024-11-22 15:16:30.985|70   |140   |
# |2024-11-22 15:16:31.035|71   |142   |
# |2024-11-22 15:16:31.085|72   |144   |
# |2024-11-22 15:16:31.135|73   |146   |
# |2024-11-22 15:16:31.185|74   |148   |
# |2024-11-22 15:16:31.235|75   |150   |
# |2024-11-22 15:16:31.285|76   |152   |
# |2024-11-22 15:16:31.335|77   |154   |
# |2024-11-22 15:16:31.385|78   |156   |
# |2024-11-22 15:16:31.435|79   |158   |
# |2024-11-22 15:16:31.485|80   |160   |
# |2024-11-22 15:16:31.535|81   |162   |
# |2024-11-22 15:16:31.585|82   |164   |
# |2024-11-22 15:16:31.635|83   |166   |
# |2024-11-22 15:16:31.685|84   |168   |
# |2024-11-22 15:16:31.735|85   |170   |
# |2024-11-22 15:16:31.785|86   |172   |
# |2024-11-22 15:16:31.835|87   |174   |
# |2024-11-22 15:16:31.885|88   |176   |
# |2024-11-22 15:16:31.935|89   |178   |
# |2024-11-22 15:16:31.985|90   |180   |
# |2024-11-22 15:16:32.035|91   |182   |
# |2024-11-22 15:16:32.085|92   |184   |
# |2024-11-22 15:16:32.135|93   |186   |
# |2024-11-22 15:16:32.185|94   |188   |
# |2024-11-22 15:16:32.235|95   |190   |
# |2024-11-22 15:16:32.285|96   |192   |
# |2024-11-22 15:16:32.335|97   |194   |
# |2024-11-22 15:16:32.385|98   |196   |
# |2024-11-22 15:16:32.435|99   |198   |
# +-----------------------+-----+------+
# only showing top 100 rows

# %%
query.lastProgress['sources'][0]['numInputRows']
# Out:
# 20

# %%
for batch in query.recentProgress:
  print(f"timestamp - {batch['timestamp']}")
  print(f"batchId - {batch['batchId']}")
  print(f"numInputRows - {batch['numInputRows']}")
  print("--")

# %%
query.stop()
