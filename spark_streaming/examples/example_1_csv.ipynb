# %% [markdown]
# <a href="https://colab.research.google.com/github/vaniamv/dataprocessing/blob/main/spark_streaming/examples/example_1_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Usecase 1
# - Defining a sample dataset
# - Splitting dataset in many CSVs and uploading them in the input folder in async mode
# - Use Spark streaming to read from input folder
# - Checking results from query in memory

# %% [markdown]
# # Setting up PySpark

# %%
# %pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession

#SparkSession.stop(spark)
spark = SparkSession.builder.master('local').appName('Test streaming').getOrCreate()
sc = spark.sparkContext

# %% [markdown]
# # Reading sample dataset

# %%
from pyspark import SparkFiles
from pyspark.sql import DataFrame
from pyspark.sql.types import *
import uuid
from pyspark.sql.functions import udf

def get_data(url: str, filename: str, schema) -> DataFrame:
  # read using SparkFiles
  spark.sparkContext.addFile(url)
  data = sc.textFile(SparkFiles.get(filename))

  # removing header
  header = data.first()
  data = data.filter(lambda line: line != header)

  df = spark.read.csv(data, header=True, schema=schema)
  return df

@udf
def generate_uuid():
  return str(uuid.uuid4())

schema = StructType([
StructField('Area Name',StringType(),True),
StructField('Area ID',StringType(),True),
StructField('Park Name',StringType(),True),
StructField('Park ID', StringType(), True),
StructField('Squirrel ID', StringType(), True),
StructField('Primary Fur Color', StringType(), True),
StructField('Highlights in Fur Color', StringType(), True),
StructField('Color Notes', StringType(), True),
StructField('Location', StringType(), True),
StructField('Above Ground (Height in Feet)', StringType(), True),
StructField('Specific Location', StringType(), True),
StructField('Activities', StringType(), True),
StructField('Interactions with Humans', StringType(), True),
StructField('Squirrel Latitude (DD.DDDDDD)', StringType(), True),
StructField('Squirrel Longitude (-DD.DDDDDD)', StringType(), True),
StructField('hash', StringType(), True)
])

df = get_data(url = "https://raw.githubusercontent.com/lucprosa/dataeng-basic-course/main/data/squirrel-data/squirrel-data.csv", filename = "squirrel-data.csv", schema = schema)
df = df.withColumn("hash", generate_uuid())

df = df.cache()
df.count()

df.show()
# Out:
# +---------------+-------+-------------------+-------+-----------+-----------------+-----------------------+-----------+------------+-----------------------------+-----------------+--------------------+------------------------+-----------------------------+-------------------------------+--------------------+
# |      Area Name|Area ID|          Park Name|Park ID|Squirrel ID|Primary Fur Color|Highlights in Fur Color|Color Notes|    Location|Above Ground (Height in Feet)|Specific Location|          Activities|Interactions with Humans|Squirrel Latitude (DD.DDDDDD)|Squirrel Longitude (-DD.DDDDDD)|                hash|
# +---------------+-------+-------------------+-------+-----------+-----------------+-----------------------+-----------+------------+-----------------------------+-----------------+--------------------+------------------------+-----------------------------+-------------------------------+--------------------+
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-02|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|            Foraging|             Indifferent|                 Looks skinny|                      40.859436|547a4524-3c8e-427...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-03|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|Eating, Digging s...|             Indifferent|                         NULL|                      40.859416|65eb4477-7105-426...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-04|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|             Running|             Indifferent|                         NULL|                      40.859418|255b2098-b7a7-48a...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-05|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|     Running, Eating|             Indifferent|                She left food|                      40.859493|6ccf396f-f03c-450...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-06|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|            Climbing|             Indifferent|                         NULL|                      40.860825|6d7e6879-94fc-476...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-07|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|            Foraging|             Indifferent|                         NULL|                      40.860225|f3e08e2f-fe22-4a0...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-08|            Black|                   Gray|       NULL|Above Ground|                           10|             NULL|            Climbing|               Runs From|                         NULL|                      40.859965|9a5a5d6f-29be-49e...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-09|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|            Foraging|             Indifferent|                         NULL|                      40.859892|c4438362-f7b4-4d7...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-10|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|     Eating, Digging|             Indifferent|                         NULL|                      40.859636|4f71d215-973e-4c2...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-11|             Gray|                  Black|       NULL|Ground Plane|                         NULL|             NULL|     Eating, Digging|             Indifferent|         was intimidated b...|                      40.859576|708df3e0-e3c2-44c...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-12|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|             Running|               Runs From|                         NULL|                      40.859989|40eb55cc-4443-482...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-01|             Gray|                   Gray|       NULL|Ground Plane|                         NULL|             NULL|             Running|             Indifferent|                         NULL|                      40.845749|09171db0-b39c-497...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-02|             Gray|               Cinnamon|       NULL|Above Ground|                            2|             NULL|            Foraging|             Indifferent|                         NULL|                      40.845875|5a6daea1-28d2-40a...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-03|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|            Foraging|                    NULL|                         NULL|                      40.845875|b45d28ed-fe95-420...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-04|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|             Running|             Indifferent|                         NULL|                      40.846088|b246e057-72fc-403...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-05|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|             Running|               Runs From|                         NULL|                      40.846088|220810cd-7b67-436...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-06|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|            Foraging|             Indifferent|                         NULL|                      40.846088|4e8335a0-87c9-4f7...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-07|             Gray|                   Gray|       NULL|Ground Plane|                         NULL|             NULL|                NULL|               Runs From|                         NULL|                      40.846222|c0ad64e7-11be-494...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-08|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|Foraging, Nesting...|             Indifferent|                         NULL|                      40.846222|d4137473-15e5-48e...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-09|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|             Chasing|             Indifferent|                         NULL|                      40.846197|6648e3ea-0123-461...|
# +---------------+-------+-------------------+-------+-----------+-----------------+-----------------------+-----------+------------+-----------------------------+-----------------+--------------------+------------------------+-----------------------------+-------------------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Removing folders

# %%
# !rm -rf /content/input/
# !rm -rf /content/output/
# !rm -rf /content/checkpoint/

# %% [markdown]
# # Splitting dataset in many CSVs and uploading them in async mode
#
# - split csv files in many small files
# - sleep some seconds between each process
# - write small file into input folder

# %%
from pyspark.sql import DataFrame
import time
import asyncio

# Function to split csv into many files (assync)
async def splitDf(df: DataFrame, weight: float, files: int):
  weights = [weight for i in range(files)]
  dfs = df.randomSplit(weights)
  return dfs

# Function to write data as csv (assync)
async def writeFile(dfs: list[DataFrame], path: str, seconds_per_file: int):
  for i in range(len(dfs)):
    df = dfs[i]
    #print(f"Writing file {path}file_{i}.csv with {df.count()} lines")
    df.write.mode("append").format("csv").save(path)
    await asyncio.sleep(seconds_per_file)

async def main(df):
  files = 20
  seconds_per_file = 10
  dfs = await splitDf(df, 1.0, files)
  asyncio.create_task(writeFile(dfs, "/content/input/", seconds_per_file))

# %% [markdown]
# # Start producer

# %%
await main(df)

# %%
# !ps #provavelmente um destes é o nosso
# Out:
#     PID TTY          TIME CMD
#       1 ?        00:00:00 docker-init
#       6 ?        00:00:02 node
#       8 ?        00:00:00 oom_monitor.sh
#      10 ?        00:00:00 run.sh
#      11 ?        00:00:00 kernel_manager_
#      40 ?        00:00:00 tail
#      46 ?        00:00:00 tail
#      71 ?        00:00:17 python3 <defunct>
#      72 ?        00:00:01 colab-fileshim.
#      89 ?        00:00:05 jupyter-noteboo
#      90 ?        00:00:00 dap_multiplexer
#     507 ?        00:00:08 python3
#     546 ?        00:00:02 python3
#     578 ?        00:00:00 language_servic
#     584 ?        00:00:17 node
#     894 ?        00:00:56 java
#    1857 ?        00:00:01 python3
#    1922 ?        00:00:00 python3
#    4436 ?        00:00:00 sleep
#    4437 ?        00:00:00 ps

# %% [markdown]
# # Defining streaming functions
#
# - streaming_1
#   - read streaming data from csv
#   - write streaming data using MEMORY
#   - query "my_query" to check results
#
# - streaming_2
#   - read streaming data from csv
#   - write streaming data as PARQUET
#       - define checkpoint
#       - trigger time of 5 seconds
#       - mode append

# %%
from pyspark.sql.streaming import StreamingQuery

def streaming_1(queryName: str) -> StreamingQuery:

  # Start read of file stream (csv) from input folder
  stream1 = spark.readStream.format('csv').schema(schema).option('header', False).load('/content/input/')

  # Check if dataframe is streaming
  print(stream1.isStreaming)

  # Start write as streaming into memory
  query = (stream1.writeStream
  .format('memory')
  .queryName(queryName)
  .trigger(processingTime='5 seconds')
  .outputMode('append')
  .start()
  )
  return query

def streaming_2() -> StreamingQuery:

  # Start read of file stream (csv) from input folder
  stream1 = spark.readStream.format('csv').schema(schema).option('header', False).load('/content/input/')

  # Check if dataframe is streaming
  print(stream1.isStreaming)

  # Start write as streaming into memory
  query = (stream1.writeStream
  .format('parquet')
  .option('path', '/content/output')
  .option('checkpointLocation', '/content/checkpoint')
  .trigger(processingTime='5 seconds')
  .outputMode('append')
  .start()
  )
  return query

# %% [markdown]
# # Start streaming_1 (memory)

# %%
query = streaming_1("qry1")
# Out:
# True
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# <ipython-input-11-574e43fb283c> in <cell line: 1>()
# ----> 1 query = streaming_1("qry1")
#
# <ipython-input-7-185ffac28beb> in streaming_1(queryName)
#      15   .trigger(processingTime='5 seconds')
#      16   .outputMode('append')
# ---> 17   .start()
#      18   )
#      19   return query
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/streaming/readwriter.py in start(self, path, format, outputMode, partitionBy, queryName, **options)
#    1525             self.queryName(queryName)
#    1526         if path is None:
# -> 1527             return self._sq(self._jwrite.start())
#    1528         else:
#    1529             return self._sq(self._jwrite.start(path))
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
#    1324
#
# /usr/local/lib/python3.10/dist-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     183                 # Hide where the exception came from that shows a non-Pythonic
#     184                 # JVM exception message.
# --> 185                 raise converted from None
#     186             else:
#     187                 raise
#
# IllegalArgumentException: Cannot start query with name qry1 as a query with that name is already active in this SparkSession

# %%
# querying data in memory
spark.sql("select count(1) from qry1").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |     432|
# +--------+

# %%
# checking results (todos os 20 já foram processados)
df.count() == spark.sql("select * from qry1").count()
# Out:
# True

# %% [markdown]
# # Stop writeStreaming

# %%
query.stop()

# %% [markdown]
# # Start streaming_2 (parquet)

# %%
query = streaming_2()
# Out:
# True

# %%
query.stop()

# %% [markdown]
# # Checking output

# %%
df.count()
# Out:
# 432

# %%
input = spark.read.format("csv").load("/content/input/*")
output = spark.read.format("parquet").schema(schema).load("/content/output/*")

print(f"input - {input.count()}")
print(f"output - {output.count()}")
# Out:
# input - 432
# output - 432

# %%
query.stop()

# %%
# Counting csv files in INPUT folder
# !ls -l /content/input | grep .csv | wc -l
# Out:
# 20

# %%
# Counting csv files in OUTPUT folder (o numero vai ser inferior pk ele vai agregando de 5-5 seg)
# !ls -l /content/output | grep .parquet | wc -l
# Out:
# 1

# %%
# check streaming query attributes
query.lastProgress
query.lastProgress['numInputRows']
query.recentProgress
query.id
query.name
query.status
# Out:
# 0

# %%
# Out:
# [{'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:31:25.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:31:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:31:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:32:10.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:32:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 6, 'triggerExecution': 6},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:32:35.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:32:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:00.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:10.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:20.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:35.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:45.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:34:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:34:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:34:30.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:34:45.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:34:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:35:10.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:35:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:35:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:35:45.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:35:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:36:05.003Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:36:20.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:36:30.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 10, 'triggerExecution': 10},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:36:45.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:36:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:37:10.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:37:25.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:37:35.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:37:45.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:37:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:38:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:38:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:38:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:38:45.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:00.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:10.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:40:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:40:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:40:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:40:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:40:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 18, 'triggerExecution': 18},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:41:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:41:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:41:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:41:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:41:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:42:00.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:42:15.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:42:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:42:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:42:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:43:05.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:43:15.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:43:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:43:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:43:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:44:05.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:44:15.003Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:44:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:44:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:44:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:45:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:45:15.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:45:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
# ...
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:46:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:46:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:47:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:47:15.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:47:25.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:47:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:47:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:48:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:48:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:48:35.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:48:45.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:48:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:49:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:49:15.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:49:25.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:49:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:49:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:50:00.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:50:10.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:50:25.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:50:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:50:55.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:51:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}}]

# %%
# checking input schema
input.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: string (nullable = true)
#  |-- _c10: string (nullable = true)
#  |-- _c11: string (nullable = true)
#  |-- _c12: string (nullable = true)
#  |-- _c13: string (nullable = true)
#  |-- _c14: string (nullable = true)
#  |-- _c15: string (nullable = true)

# %%
# checking output schema
output.printSchema()
# Out:
# root
#  |-- Area Name: string (nullable = true)
#  |-- Area ID: string (nullable = true)
#  |-- Park Name: string (nullable = true)
#  |-- Park ID: string (nullable = true)
#  |-- Squirrel ID: string (nullable = true)
#  |-- Primary Fur Color: string (nullable = true)
#  |-- Highlights in Fur Color: string (nullable = true)
#  |-- Color Notes: string (nullable = true)
#  |-- Location: string (nullable = true)
#  |-- Above Ground (Height in Feet): string (nullable = true)
#  |-- Specific Location: string (nullable = true)
#  |-- Activities: string (nullable = true)
#  |-- Interactions with Humans: string (nullable = true)
#  |-- Squirrel Latitude (DD.DDDDDD): string (nullable = true)
#  |-- Squirrel Longitude (-DD.DDDDDD): string (nullable = true)
#  |-- hash: string (nullable = true)
